# %% [markdown]
# ### EDA

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import statsmodels.api as sm

# %%
car=pd.read_csv('data/Cars93.csv')
car
# Out:
#     id Manufacturer    Model     Type  Min.Price  Price  Max.Price  MPG.city  \
# 0    1        Acura  Integra    Small       12.9   15.9       18.8        25
# 1    2        Acura   Legend  Midsize       29.2   33.9       38.7        18
# 2    3         Audi       90  Compact       25.9   29.1       32.3        20
# 3    4         Audi      100  Midsize       30.8   37.7       44.6        19
# 4    5          BMW     535i  Midsize       23.7   30.0       36.2        22
# ..  ..          ...      ...      ...        ...    ...        ...       ...
# 88  89   Volkswagen  Eurovan      Van       16.6   19.7       22.7        17
# 89  90   Volkswagen   Passat  Compact       17.6   20.0       22.4        21
# 90  91   Volkswagen  Corrado   Sporty       22.9   23.3       23.7        18
# 91  92        Volvo      240  Compact       21.8   22.7       23.5        21
# 92  93        Volvo      850  Midsize       24.8   26.7       28.5        20
#
# ...

# %%
car.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 93 entries, 0 to 92
# Data columns (total 28 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   id                  93 non-null     int64
#  1   Manufacturer        93 non-null     object
#  2   Model               93 non-null     object
#  3   Type                93 non-null     object
#  4   Min.Price           93 non-null     float64
#  5   Price               93 non-null     float64
#  6   Max.Price           93 non-null     float64
#  7   MPG.city            93 non-null     int64
#  8   MPG.highway         93 non-null     int64
#  9   AirBags             56 non-null     object
#  10  DriveTrain          93 non-null     object
#  11  Cylinders           93 non-null     object
#  12  EngineSize          93 non-null     float64
#  13  Horsepower          93 non-null     int64
#  14  RPM                 93 non-null     int64
# ...

# %%
# Descriptive statistics for numerical columns
car.describe()
# Out:
#               id  Min.Price      Price  Max.Price   MPG.city  MPG.highway  \
# count  93.000000  93.000000  93.000000  93.000000  93.000000    93.000000
# mean   47.000000  17.125806  19.509677  21.898925  22.365591    29.086022
# std    26.990739   8.746029   9.659430  11.030457   5.619812     5.331726
# min     1.000000   6.700000   7.400000   7.900000  15.000000    20.000000
# 25%    24.000000  10.800000  12.200000  14.700000  18.000000    26.000000
# 50%    47.000000  14.700000  17.700000  19.600000  21.000000    28.000000
# 75%    70.000000  20.300000  23.300000  25.300000  25.000000    31.000000
# max    93.000000  45.400000  61.900000  80.000000  46.000000    50.000000
#
#        EngineSize  Horsepower          RPM  Rev.per.mile  Fuel.tank.capacity  \
# count   93.000000   93.000000    93.000000     93.000000           93.000000
# mean     2.667742  143.827957  5280.645161   2332.204301           16.664516
# ...

# %%
car.select_dtypes(include='object')
# Out:
#    Manufacturer    Model     Type             AirBags DriveTrain Cylinders  \
# 0         Acura  Integra    Small                 NaN      Front         4
# 1         Acura   Legend  Midsize  Driver & Passenger      Front         6
# 2          Audi       90  Compact         Driver only      Front         6
# 3          Audi      100  Midsize                 NaN      Front         6
# 4           BMW     535i  Midsize         Driver only       Rear         4
# ..          ...      ...      ...                 ...        ...       ...
# 88   Volkswagen  Eurovan      Van                 NaN      Front         5
# 89   Volkswagen   Passat  Compact                 NaN      Front         4
# 90   Volkswagen  Corrado   Sporty                 NaN      Front         6
# 91        Volvo      240  Compact         Driver only       Rear         4
# 92        Volvo      850  Midsize  Driver & Passenger      Front         5
#
#    Man.trans.avail   Origin                Make
# ...

# %%
car['Cylinders'].unique()
# Out:
# array(['4', '6', '8', '3', 'rotary', '5'], dtype=object)

# %%
car['Cylinders'].value_counts()
# Out:
# Cylinders
# 4         49
# 6         31
# 8          7
# 3          3
# 5          2
# rotary     1
# Name: count, dtype: int64

# %%
car2=car.select_dtypes(exclude='object')
car2
# Out:
#     id  Min.Price  Price  Max.Price  MPG.city  MPG.highway  EngineSize  \
# 0    1       12.9   15.9       18.8        25           31         1.8
# 1    2       29.2   33.9       38.7        18           25         3.2
# 2    3       25.9   29.1       32.3        20           26         2.8
# 3    4       30.8   37.7       44.6        19           26         2.8
# 4    5       23.7   30.0       36.2        22           30         3.5
# ..  ..        ...    ...        ...       ...          ...         ...
# 88  89       16.6   19.7       22.7        17           21         2.5
# 89  90       17.6   20.0       22.4        21           30         2.0
# 90  91       22.9   23.3       23.7        18           25         2.8
# 91  92       21.8   22.7       23.5        21           28         2.3
# 92  93       24.8   26.7       28.5        20           28         2.4
#
#     Horsepower   RPM  Rev.per.mile  Fuel.tank.capacity  Passengers  Length  \
# ...

# %%
car2.nunique()
# Out:
# id                    93
# Min.Price             79
# Price                 81
# Max.Price             79
# MPG.city              21
# MPG.highway           22
# EngineSize            26
# Horsepower            57
# RPM                   24
# Rev.per.mile          78
# Fuel.tank.capacity    38
# Passengers             6
# Length                51
# Wheelbase             27
# Width                 16
# Turn.circle           14
# Rear.seat.room        24
# Luggage.room          16
# Weight                81
# dtype: int64

# %%
car2['Passengers'].unique()
# Out:
# array([5, 6, 4, 7, 8, 2])

# %%
# Box plot to identify outliers
sns.boxplot(x=car['Price'])
plt.show()

# %%
# Z-score for outlier detection
from scipy import stats
z_scores = stats.zscore(car['Price'])
outliers = car[np.abs(z_scores) > 2]
# Out:
#     id   Manufacturer    Model     Type  Min.Price  Price  Max.Price  \
# 10  11       Cadillac  Seville  Midsize       37.5   40.1       42.7
# 47  48       Infiniti      Q45  Midsize       45.4   47.9       50.4
# 58  59  Mercedes-Benz     300E  Midsize       43.8   61.9       80.0
#
#     MPG.city  MPG.highway             AirBags  ... Passengers Length  \
# 10        16           25  Driver & Passenger  ...          5    204
# 47        17           22         Driver only  ...          5    200
# 58        19           25  Driver & Passenger  ...          5    187
#
#     Wheelbase  Width  Turn.circle  Rear.seat.room Luggage.room  Weight  \
# 10        111     74           44            31.0         14.0    3935
# 47        113     72           42            29.0         15.0    4000
# 58        110     69           37            27.0         15.0    3525
#
#      Origin                Make
# 10      USA    Cadillac Seville
# 47  non-USA        Infiniti Q45
# ...

# %%
pd.crosstab(index=car['Type'],
            columns=car['Man.trans.avail'],
            normalize=True,
            dropna=True,
            margins=True)
# Out:
# Man.trans.avail        No       Yes       All
# Type
# Compact          0.021505  0.150538  0.172043
# Large            0.118280  0.000000  0.118280
# Midsize          0.139785  0.096774  0.236559
# Small            0.000000  0.225806  0.225806
# Sporty           0.000000  0.150538  0.150538
# Van              0.064516  0.032258  0.096774
# All              0.344086  0.655914  1.000000

# %%
# Correlation matrix
correlation_matrix = car.corr(numeric_only=True) 
correlation_matrix
# Out:
#                           id  Min.Price     Price  Max.Price  MPG.city  \
# id                  1.000000  -0.144463 -0.137277  -0.126567  0.161808
# Min.Price          -0.144463   1.000000  0.970601   0.906756 -0.622875
# Price              -0.137277   0.970601  1.000000   0.981580 -0.594562
# Max.Price          -0.126567   0.906756  0.981580   1.000000 -0.547811
# MPG.city            0.161808  -0.622875 -0.594562  -0.547811  1.000000
# MPG.highway         0.137317  -0.579966 -0.560680  -0.522561  0.943936
# EngineSize         -0.338286   0.645488  0.597425   0.535012 -0.710003
# Horsepower         -0.233012   0.802444  0.788218   0.744445 -0.672636
# RPM                 0.167772  -0.042598 -0.004955   0.025015  0.363045
# Rev.per.mile        0.226389  -0.470395 -0.426395  -0.374024  0.695857
# Fuel.tank.capacity -0.179034   0.635369  0.619480   0.581294 -0.813144
# Passengers         -0.142252   0.061236  0.057860   0.053216 -0.416856
# ...

# %% [markdown]
# ### Graphs and Trends

# %%
plt.figure(figsize=(10,6))
plt.boxplot(x=car['Price'], vert=False)
plt.title('Boxplot of Car Prices')
plt.xlabel('Price')
plt.show()

# %%
sns.histplot(car,x='Price',kde=True)
plt.show()

# %%
car['Price'].plot(kind='density')
# Out:
# <Axes: ylabel='Density'>

# %%
sm.qqplot(data=car['Price'],line='s')
